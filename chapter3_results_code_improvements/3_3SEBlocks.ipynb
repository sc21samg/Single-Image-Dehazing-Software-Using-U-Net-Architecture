# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate, Activation, Conv2DTranspose,
                                     BatchNormalization, GlobalAveragePooling2D, Reshape, Dense, multiply)
from tensorflow.keras.models import Model

# Squeeze and Excite block
def squeeze_excite_block(input_tensor, ratio=16):
    init = input_tensor
    channel_axis = -1
    filters = init.shape[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(se_shape)(se)
    se = Dense(filters // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(se)

    x = multiply([init, se])
    return x

# Define a convolutional block
def conv_block(x, num_filters):
    x = Conv2D(num_filters, (3, 3), padding='same', kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters, (3, 3), padding='same', kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# Build U-Net model incorporating Squeeze and Excite blocks
def build_unet(input_size=(256, 256, 3)):
    inputs = Input(input_size)

    # Contracting Path (Encoder)
    c1 = conv_block(inputs, 64)
    c1 = squeeze_excite_block(c1)  # Add squeeze and excite block
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = conv_block(p1, 128)
    c2 = squeeze_excite_block(c2)  # Add squeeze and excite block
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = conv_block(p2, 256)
    c3 = squeeze_excite_block(c3)  # Add squeeze and excite block
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = conv_block(p3, 512)
    c4 = squeeze_excite_block(c4)  # Add squeeze and excite block
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = conv_block(p4, 1024)
    c5 = squeeze_excite_block(c5)  # Add squeeze and excite block

    # Expansive Path (Decoder)
    u4 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c5)
    u4 = Concatenate()([u4, c4])
    c6 = conv_block(u4, 512)
    c6 = squeeze_excite_block(c6)  # Add squeeze and excite block

    u3 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
    u3 = Concatenate()([u3, c3])
    c7 = conv_block(u3, 256)
    c7 = squeeze_excite_block(c7)  # Add squeeze and excite block

    u2 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
    u2 = Concatenate()([u2, c2])
    c8 = conv_block(u2, 128)
    c8 = squeeze_excite_block(c8)  # Add squeeze and excite block

    u1 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
    u1 = Concatenate()([u1, c1])
    c9 = conv_block(u1, 64)
    c9 = squeeze_excite_block(c9)  # Add squeeze and excite block

    # Output layer
    outputs = Conv2D(3, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs=inputs, outputs=outputs)
    return model

# Metrics
def psnr_metric(y_true, y_pred):
    # Peak Signal-to-Noise Ratio metric
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

def ssim_metric(y_true, y_pred):
    # Structural Similarity Index
    y_true_f32 = tf.cast(y_true, tf.float32)
    y_pred_f32 = tf.cast(y_pred, tf.float32)
    return tf.image.ssim(y_true_f32, y_pred_f32, max_val=1.0)

# Example usage
model = build_unet((256, 256, 3))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=[psnr_metric, ssim_metric])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_19 (Conv2D)          (None, 256, 256, 64)         1792      ['input_2[0][0]']
#
#  batch_normalization_18 (Ba  (None, 256, 256, 64)         256       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 256, 256, 64)         36928     ['activation_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 256, 256, 64)         256       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  global_average_pooling2d (  (None, 64)                   0         ['activation_19[0][0]']
#  GlobalAveragePooling2D)
#
#  reshape (Reshape)           (None, 1, 1, 64)             0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 1, 1, 4)              256       ['reshape[0][0]']
#
#  dense_1 (Dense)             (None, 1, 1, 64)             256       ['dense[0][0]']
#
#  multiply (Multiply)         (None, 256, 256, 64)         0         ['activation_19[0][0]',
#                                                                      'dense_1[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 128, 128, 64)         0         ['multiply[0][0]']
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 128, 128, 128)        73856     ['max_pooling2d_4[0][0]']
#
#  batch_normalization_20 (Ba  (None, 128, 128, 128)        512       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 128, 128, 128)        147584    ['activation_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 128, 128, 128)        512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 128)                  0         ['activation_21[0][0]']
#   (GlobalAveragePooling2D)
#
#  reshape_1 (Reshape)         (None, 1, 1, 128)            0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dense_2 (Dense)             (None, 1, 1, 8)              1024      ['reshape_1[0][0]']
#
#  dense_3 (Dense)             (None, 1, 1, 128)            1024      ['dense_2[0][0]']
#
#  multiply_1 (Multiply)       (None, 128, 128, 128)        0         ['activation_21[0][0]',
#                                                                      'dense_3[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 64, 64, 128)          0         ['multiply_1[0][0]']
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 256)          295168    ['max_pooling2d_5[0][0]']
#
#  batch_normalization_22 (Ba  (None, 64, 64, 256)          1024      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 256)          590080    ['activation_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 64, 64, 256)          1024      ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  global_average_pooling2d_2  (None, 256)                  0         ['activation_23[0][0]']
#   (GlobalAveragePooling2D)
#
#  reshape_2 (Reshape)         (None, 1, 1, 256)            0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dense_4 (Dense)             (None, 1, 1, 16)             4096      ['reshape_2[0][0]']
#
#  dense_5 (Dense)             (None, 1, 1, 256)            4096      ['dense_4[0][0]']
#
#  multiply_2 (Multiply)       (None, 64, 64, 256)          0         ['activation_23[0][0]',
#                                                                      'dense_5[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 32, 32, 256)          0         ['multiply_2[0][0]']
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 512)          1180160   ['max_pooling2d_6[0][0]']
#
#  batch_normalization_24 (Ba  (None, 32, 32, 512)          2048      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 32, 32, 512)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 32, 32, 512)          2359808   ['activation_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 32, 32, 512)          2048      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 32, 32, 512)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  global_average_pooling2d_3  (None, 512)                  0         ['activation_25[0][0]']
#   (GlobalAveragePooling2D)
#
#  reshape_3 (Reshape)         (None, 1, 1, 512)            0         ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  dense_6 (Dense)             (None, 1, 1, 32)             16384     ['reshape_3[0][0]']
#
#  dense_7 (Dense)             (None, 1, 1, 512)            16384     ['dense_6[0][0]']
#
#  multiply_3 (Multiply)       (None, 32, 32, 512)          0         ['activation_25[0][0]',
#                                                                      'dense_7[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 16, 16, 512)          0         ['multiply_3[0][0]']
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 16, 16, 1024)         4719616   ['max_pooling2d_7[0][0]']
#
#  batch_normalization_26 (Ba  (None, 16, 16, 1024)         4096      ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 16, 16, 1024)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 16, 16, 1024)         9438208   ['activation_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 16, 16, 1024)         4096      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 16, 16, 1024)         0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  global_average_pooling2d_4  (None, 1024)                 0         ['activation_27[0][0]']
#   (GlobalAveragePooling2D)
#
#  reshape_4 (Reshape)         (None, 1, 1, 1024)           0         ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
#  dense_8 (Dense)             (None, 1, 1, 64)             65536     ['reshape_4[0][0]']
#
#  dense_9 (Dense)             (None, 1, 1, 1024)           65536     ['dense_8[0][0]']
#
#  multiply_4 (Multiply)       (None, 16, 16, 1024)         0         ['activation_27[0][0]',
#                                                                      'dense_9[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 32, 32, 512)          2097664   ['multiply_4[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 32, 32, 1024)         0         ['conv2d_transpose_4[0][0]',
#  )                                                                   'multiply_3[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 512)          4719104   ['concatenate_4[0][0]']
#
#  batch_normalization_28 (Ba  (None, 32, 32, 512)          2048      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 32, 32, 512)          0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 32, 32, 512)          2359808   ['activation_28[0][0]']
#
#  batch_normalization_29 (Ba  (None, 32, 32, 512)          2048      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 32, 32, 512)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  global_average_pooling2d_5  (None, 512)                  0         ['activation_29[0][0]']
#   (GlobalAveragePooling2D)
#
#  reshape_5 (Reshape)         (None, 1, 1, 512)            0         ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  dense_10 (Dense)            (None, 1, 1, 32)             16384     ['reshape_5[0][0]']
#
#  dense_11 (Dense)            (None, 1, 1, 512)            16384     ['dense_10[0][0]']
#
#  multiply_5 (Multiply)       (None, 32, 32, 512)          0         ['activation_29[0][0]',
#                                                                      'dense_11[0][0]']
#
#  conv2d_transpose_5 (Conv2D  (None, 64, 64, 256)          524544    ['multiply_5[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 64, 64, 512)          0         ['conv2d_transpose_5[0][0]',
#  )                                                                   'multiply_2[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 64, 64, 256)          1179904   ['concatenate_5[0][0]']
#
#  batch_normalization_30 (Ba  (None, 64, 64, 256)          1024      ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 64, 64, 256)          590080    ['activation_30[0][0]']
#
#  batch_normalization_31 (Ba  (None, 64, 64, 256)          1024      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  global_average_pooling2d_6  (None, 256)                  0         ['activation_31[0][0]']
#   (GlobalAveragePooling2D)
#
#  reshape_6 (Reshape)         (None, 1, 1, 256)            0         ['global_average_pooling2d_6[0
#                                                                     ][0]']
#
#  dense_12 (Dense)            (None, 1, 1, 16)             4096      ['reshape_6[0][0]']
#
#  dense_13 (Dense)            (None, 1, 1, 256)            4096      ['dense_12[0][0]']
#
#  multiply_6 (Multiply)       (None, 64, 64, 256)          0         ['activation_31[0][0]',
#                                                                      'dense_13[0][0]']
#
#  conv2d_transpose_6 (Conv2D  (None, 128, 128, 128)        131200    ['multiply_6[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 128, 128, 256)        0         ['conv2d_transpose_6[0][0]',
#  )                                                                   'multiply_1[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 128, 128, 128)        295040    ['concatenate_6[0][0]']
#
#  batch_normalization_32 (Ba  (None, 128, 128, 128)        512       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 128, 128, 128)        147584    ['activation_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 128, 128, 128)        512       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  global_average_pooling2d_7  (None, 128)                  0         ['activation_33[0][0]']
#   (GlobalAveragePooling2D)
#
#  reshape_7 (Reshape)         (None, 1, 1, 128)            0         ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
#  dense_14 (Dense)            (None, 1, 1, 8)              1024      ['reshape_7[0][0]']
#
#  dense_15 (Dense)            (None, 1, 1, 128)            1024      ['dense_14[0][0]']
#
#  multiply_7 (Multiply)       (None, 128, 128, 128)        0         ['activation_33[0][0]',
#                                                                      'dense_15[0][0]']
#
#  conv2d_transpose_7 (Conv2D  (None, 256, 256, 64)         32832     ['multiply_7[0][0]']
#  Transpose)
#
#  concatenate_7 (Concatenate  (None, 256, 256, 128)        0         ['conv2d_transpose_7[0][0]',
#  )                                                                   'multiply[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 256, 256, 64)         73792     ['concatenate_7[0][0]']
#
#  batch_normalization_34 (Ba  (None, 256, 256, 64)         256       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 256, 256, 64)         36928     ['activation_34[0][0]']
#
#  batch_normalization_35 (Ba  (None, 256, 256, 64)         256       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  global_average_pooling2d_8  (None, 64)                   0         ['activation_35[0][0]']
#   (GlobalAveragePooling2D)
#
#  reshape_8 (Reshape)         (None, 1, 1, 64)             0         ['global_average_pooling2d_8[0
#                                                                     ][0]']
#
#  dense_16 (Dense)            (None, 1, 1, 4)              256       ['reshape_8[0][0]']
#
#  dense_17 (Dense)            (None, 1, 1, 64)             256       ['dense_16[0][0]']
#
#  multiply_8 (Multiply)       (None, 256, 256, 64)         0         ['activation_35[0][0]',
#                                                                      'dense_17[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 256, 256, 3)          195       ['multiply_8[0][0]']
#
# ==================================================================================================
# Total params: 31273539 (119.30 MB)
# Trainable params: 31261763 (119.25 MB)
# Non-trainable params: 11776 (46.00 KB)
# __________________________________________________________________________________________________

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)

import tensorflow as tf
import os

def decode_img(img, image_size=(256, 256)):
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, image_size)
    img /= 255.0  # Normalize to [0,1]
    return img

def process_path(clear_path, hazy_path):
    print(f"Processing: {clear_path} and {hazy_path}")  # Print the paths being processed
    clear_img = tf.io.read_file(clear_path)
    clear_img = decode_img(clear_img)
    hazy_img = tf.io.read_file(hazy_path)
    hazy_img = decode_img(hazy_img)
    return hazy_img, clear_img

def create_dataset(dir_pairs, image_size=(256, 256), batch_size=32, shuffle=True):
    clear_paths, hazy_paths = [], []

    print("Collecting image paths...")
    # Collect paths of both clear and corresponding hazy images
    for clear_dir, hazy_dir in dir_pairs:
        # Assuming file names match except for the "foggy_beta" part
        for file_name in sorted(os.listdir(clear_dir)):
            if not file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
                continue

            base_name = '_'.join(file_name.split('_')[:-1])
            for beta in ["0.01", "0.02", "0.005"]:
                hazy_file_name = f"{base_name}_leftImg8bit_foggy_beta_{beta}.png"
                hazy_path = os.path.join(hazy_dir, hazy_file_name)
                if os.path.exists(hazy_path):
                    clear_paths.append(os.path.join(clear_dir, file_name))
                    hazy_paths.append(hazy_path)

    print(f"Collected {len(clear_paths)} pairs of images.")

    # Create a tf.data.Dataset from paths
    dataset = tf.data.Dataset.from_tensor_slices((clear_paths, hazy_paths))
    print("Creating dataset from paths...")
    dataset = dataset.map(lambda x, y: process_path(x, y), num_parallel_calls=tf.data.AUTOTUNE)

    if shuffle:
        print("Shuffling dataset...")
        dataset = dataset.shuffle(buffer_size=len(clear_paths))

    print("Batching dataset...")
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    print("Dataset created and ready for use.")
    return dataset

# Define the pairs of directories
dir_pairs = [
    ('/content/drive/My Drive/diss/myproj/data_train/clear_images/strasbourg', '/content/drive/My Drive/diss/myproj/data_train/hazy_images/strasbourg'),
    ('/content/drive/My Drive/diss/myproj/data_train/clear_images/hamburg', '/content/drive/My Drive/diss/myproj/data_train/hazy_images/hamburg'),
    ('/content/drive/My Drive/diss/myproj/data_train/clear_images/aachen', '/content/drive/My Drive/diss/myproj/data_train/hazy_images/aachen'),
    ('/content/drive/My Drive/diss/myproj/data_train/clear_images/hanover', '/content/drive/My Drive/diss/myproj/data_train/hazy_images/hanover')
]

# Create and use the TensorFlow dataset
print("Starting dataset creation...")
dataset = create_dataset(dir_pairs)

# Display some info about the dataset (optional)
for hazy_images, clear_images in dataset.take(1):
    print(f"Sample batch - Hazy images shape: {hazy_images.shape}, dtype: {hazy_images.dtype}")
    print(f"Sample batch - Clear images shape: {clear_images.shape}, dtype: {clear_images.dtype}")

#####################

import tensorflow as tf

# Clear any previous session
tf.keras.backend.clear_session()

# Set the mixed precision policy
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('float32')


from tensorflow.keras.optimizers import Adam
#from dehaze import model, build_unet, my_loss, psnr_metric, ssim_metric  # Adjust import according to your file structure
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
#from dataset import hazy_images, clear_images_matched  # Assuming these are loaded and prepared as shown
import matplotlib.pyplot as plt
from tensorflow.image import psnr, ssim

# Assuming `dataset` is your complete dataset returned from `create_dataset`
# First, let's count the number of items in the dataset
dataset_size = len(dataset)
train_size = int(0.8 * dataset_size)
val_size = dataset_size - train_size

# Split the dataset into training and validation sets
full_dataset = dataset.shuffle(buffer_size=dataset_size)
train_dataset = full_dataset.take(train_size)
val_dataset = full_dataset.skip(train_size)

# Continue with your model definition and training as before
# Ensure you use `train_dataset` and `val_dataset` for training and validation, respectively.



def create_dataset_from_paths(hazy_paths, clear_paths, image_size=(256, 256), batch_size=32, shuffle=True):
    dataset = tf.data.Dataset.from_tensor_slices((hazy_paths, clear_paths))
    dataset = dataset.map(lambda x, y: process_path(x, y), num_parallel_calls=tf.data.AUTOTUNE)

    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(hazy_paths))

    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset


# Load and prepare your data
# Ensure datasets are TensorFlow Dataset objects correctly batched
def prepare_tf_dataset(hazy_images, clear_images, batch_size=6):
    dataset = tf.data.Dataset.from_tensor_slices((hazy_images, clear_images))
    dataset = dataset.shuffle(buffer_size=len(hazy_images)).batch(batch_size)
    return dataset

# Split the data into training and validation sets
train_size = int(0.8 * len(hazy_images))
train_hazy, train_clear = hazy_images[:train_size], clear_images[:train_size]
val_hazy, val_clear = hazy_images[train_size:], clear_images[train_size:]

# Prepare TensorFlow datasets
train_dataset = prepare_tf_dataset(train_hazy, train_clear, batch_size=6)
val_dataset = prepare_tf_dataset(val_hazy, val_clear, batch_size=6)


# Assume load_datasets returns properly prepared and normalized TensorFlow Dataset objects
#train_dataset, val_dataset = load_datasets()

# Build the model
model = build_unet((256, 256, 3))

# Define a learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-4,
    decay_steps=10000,
    decay_rate=0.9,
    staircase=True)

# Compile the model using Mean Squared Error (MSE) as the loss function
model.compile(optimizer=Adam(learning_rate=lr_schedule),
              loss='mean_squared_error',  # Using built-in MSE loss
              metrics=[psnr_metric, ssim_metric])



# Custom callback for epoch printing
class TrainingPrint(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        print(f"Starting Epoch {epoch+1}")


early_stopping_callback = EarlyStopping(
    monitor='val_loss',
    patience=10,  # Number of epochs with no improvement after which training will be stopped
    verbose=1,
    mode='min')



# Train the model
history = model.fit(
    train_dataset,
    epochs = 30,
    validation_data=val_dataset,
    callbacks=[ early_stopping_callback, TrainingPrint()])


# Save the final model
model.save('/content/drive/My Drive/diss/myproj/results/3_3SEBlocks.keras')

# Evaluate the model on the validation dataset
val_loss, val_psnr, val_ssim = model.evaluate(val_dataset)
print(f"Validation Loss: {val_loss}, Validation PSNR: {val_psnr}, Validation SSIM: {val_ssim}")

# Plotting the training history (loss, PSNR, SSIM)
# You can use the plotting code you've provided to visualize the training and validation metrics over epochs.
# Out:
# Mounted at /content/drive
# Starting dataset creation...
# Collecting image paths...
# Collected 2949 pairs of images.
# Creating dataset from paths...
# Processing: Tensor("args_0:0", shape=(), dtype=string) and Tensor("args_1:0", shape=(), dtype=string)
# Shuffling dataset...
# Batching dataset...
# Dataset created and ready for use.
# Sample batch - Hazy images shape: (32, 256, 256, 3), dtype: <dtype: 'float32'>
# Sample batch - Clear images shape: (32, 256, 256, 3), dtype: <dtype: 'float32'>
# Starting Epoch 1
# Epoch 1/30
# 5/5 [==============================] - 19s 464ms/step - loss: 0.0690 - psnr_metric: 11.7031 - ssim_metric: 0.2135 - val_loss: 0.0733 - val_psnr_metric: 11.4681 - val_ssim_metric: 0.4224
# Starting Epoch 2
# Epoch 2/30
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0537 - psnr_metric: 12.7980 - ssim_metric: 0.2778 - val_loss: 0.0772 - val_psnr_metric: 11.2184 - val_ssim_metric: 0.4261
# Starting Epoch 3
# Epoch 3/30
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0481 - psnr_metric: 13.3322 - ssim_metric: 0.3296 - val_loss: 0.0788 - val_psnr_metric: 11.1129 - val_ssim_metric: 0.4317
# Starting Epoch 4
# Epoch 4/30
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0426 - psnr_metric: 13.8455 - ssim_metric: 0.3813 - val_loss: 0.0772 - val_psnr_metric: 11.2039 - val_ssim_metric: 0.4354
# Starting Epoch 5
# Epoch 5/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0390 - psnr_metric: 14.2506 - ssim_metric: 0.4147 - val_loss: 0.0747 - val_psnr_metric: 11.3435 - val_ssim_metric: 0.4374
# Starting Epoch 6
# Epoch 6/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0350 - psnr_metric: 14.6756 - ssim_metric: 0.4451 - val_loss: 0.0725 - val_psnr_metric: 11.4805 - val_ssim_metric: 0.4374
# Starting Epoch 7
# Epoch 7/30
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0315 - psnr_metric: 15.1979 - ssim_metric: 0.4709 - val_loss: 0.0700 - val_psnr_metric: 11.6395 - val_ssim_metric: 0.4372
# Starting Epoch 8
# Epoch 8/30
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0286 - psnr_metric: 15.5832 - ssim_metric: 0.4888 - val_loss: 0.0687 - val_psnr_metric: 11.7241 - val_ssim_metric: 0.4376
# Starting Epoch 9
# Epoch 9/30
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0251 - psnr_metric: 16.1769 - ssim_metric: 0.5071 - val_loss: 0.0674 - val_psnr_metric: 11.8088 - val_ssim_metric: 0.4383
# Starting Epoch 10
# Epoch 10/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0229 - psnr_metric: 16.5191 - ssim_metric: 0.5204 - val_loss: 0.0664 - val_psnr_metric: 11.8760 - val_ssim_metric: 0.4392
# Starting Epoch 11
# Epoch 11/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0219 - psnr_metric: 16.8028 - ssim_metric: 0.5360 - val_loss: 0.0647 - val_psnr_metric: 11.9807 - val_ssim_metric: 0.4374
# Starting Epoch 12
# Epoch 12/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0210 - psnr_metric: 17.0171 - ssim_metric: 0.5556 - val_loss: 0.0635 - val_psnr_metric: 12.0721 - val_ssim_metric: 0.4378
# Starting Epoch 13
# Epoch 13/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0191 - psnr_metric: 17.4068 - ssim_metric: 0.5695 - val_loss: 0.0630 - val_psnr_metric: 12.1142 - val_ssim_metric: 0.4390
# Starting Epoch 14
# Epoch 14/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0171 - psnr_metric: 17.8420 - ssim_metric: 0.5785 - val_loss: 0.0629 - val_psnr_metric: 12.1294 - val_ssim_metric: 0.4391
# Starting Epoch 15
# Epoch 15/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0160 - psnr_metric: 18.1388 - ssim_metric: 0.6010 - val_loss: 0.0620 - val_psnr_metric: 12.1860 - val_ssim_metric: 0.4433
# Starting Epoch 16
# Epoch 16/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0157 - psnr_metric: 18.2964 - ssim_metric: 0.6145 - val_loss: 0.0612 - val_psnr_metric: 12.2411 - val_ssim_metric: 0.4464
# Starting Epoch 17
# Epoch 17/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0152 - psnr_metric: 18.4342 - ssim_metric: 0.6215 - val_loss: 0.0601 - val_psnr_metric: 12.3163 - val_ssim_metric: 0.4510
# Starting Epoch 18
# Epoch 18/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0133 - psnr_metric: 19.0111 - ssim_metric: 0.6370 - val_loss: 0.0596 - val_psnr_metric: 12.3630 - val_ssim_metric: 0.4517
# Starting Epoch 19
# Epoch 19/30
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0130 - psnr_metric: 19.1100 - ssim_metric: 0.6409 - val_loss: 0.0594 - val_psnr_metric: 12.3731 - val_ssim_metric: 0.4528
# Starting Epoch 20
# Epoch 20/30
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0122 - psnr_metric: 19.3472 - ssim_metric: 0.6469 - val_loss: 0.0582 - val_psnr_metric: 12.4601 - val_ssim_metric: 0.4573
# Starting Epoch 21
# Epoch 21/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0124 - psnr_metric: 19.2775 - ssim_metric: 0.6527 - val_loss: 0.0574 - val_psnr_metric: 12.5178 - val_ssim_metric: 0.4604
# Starting Epoch 22
# Epoch 22/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0121 - psnr_metric: 19.5065 - ssim_metric: 0.6605 - val_loss: 0.0554 - val_psnr_metric: 12.6772 - val_ssim_metric: 0.4664
# Starting Epoch 23
# Epoch 23/30
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0104 - psnr_metric: 20.0327 - ssim_metric: 0.6740 - val_loss: 0.0551 - val_psnr_metric: 12.7077 - val_ssim_metric: 0.4692
# Starting Epoch 24
# Epoch 24/30
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0104 - psnr_metric: 20.0516 - ssim_metric: 0.6800 - val_loss: 0.0536 - val_psnr_metric: 12.8200 - val_ssim_metric: 0.4760
# Starting Epoch 25
# Epoch 25/30
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0095 - psnr_metric: 20.4377 - ssim_metric: 0.6826 - val_loss: 0.0528 - val_psnr_metric: 12.8929 - val_ssim_metric: 0.4793
# Starting Epoch 26
# Epoch 26/30
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0092 - psnr_metric: 20.5346 - ssim_metric: 0.6898 - val_loss: 0.0511 - val_psnr_metric: 13.0321 - val_ssim_metric: 0.4849
# Starting Epoch 27
# Epoch 27/30
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0087 - psnr_metric: 20.7863 - ssim_metric: 0.6939 - val_loss: 0.0508 - val_psnr_metric: 13.0561 - val_ssim_metric: 0.4897
# Starting Epoch 28
# Epoch 28/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0084 - psnr_metric: 21.0090 - ssim_metric: 0.7018 - val_loss: 0.0482 - val_psnr_metric: 13.2924 - val_ssim_metric: 0.4962
# Starting Epoch 29
# Epoch 29/30
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0089 - psnr_metric: 20.6596 - ssim_metric: 0.7064 - val_loss: 0.0481 - val_psnr_metric: 13.3037 - val_ssim_metric: 0.5002
# Starting Epoch 30
# Epoch 30/30
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0083 - psnr_metric: 21.0912 - ssim_metric: 0.7174 - val_loss: 0.0453 - val_psnr_metric: 13.5579 - val_ssim_metric: 0.5070
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0453 - psnr_metric: 13.5579 - ssim_metric: 0.5070
# Validation Loss: 0.045338697731494904, Validation PSNR: 13.557860374450684, Validation SSIM: 0.5069888830184937
